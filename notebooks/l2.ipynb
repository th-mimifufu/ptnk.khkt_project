# %%
import pandas as pd
import openpyxl

# %%
data = pd.read_excel("../../data/fm_l2_updated.xlsx")

# %%
data
# Out:
#       Tổ hợp môn  Điểm chuẩn     Học phí tên ccta điểm ccta  điểm quy đổi  \
# 0         VNUHCM      617.00  14100000.0        0         0           0.0
# 1         VNUHCM      635.00  14100000.0        0         0           0.0
# 2         VNUHCM      614.00  14100000.0        0         0           0.0
# 3         VNUHCM      831.00  14100000.0        0         0           0.0
# 4         VNUHCM      688.00  14100000.0        0         0           0.0
# ...          ...         ...         ...      ...       ...           ...
# 13265        D15       27.85  15000000.0        0         0           0.0
# 13266        C00       25.50  15000000.0        0         0           0.0
# 13267        D01       25.50  15000000.0        0         0           0.0
# 13268        D09       25.50  15000000.0        0         0           0.0
# 13269        D15       25.50  15000000.0        0         0           0.0
#
#        hk10  hk11  hk12  hl10  hl11  hl12  nhom_nganh      ma_xet_tuyen
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13270 entries, 0 to 13269
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tổ hợp môn    13206 non-null  object
#  1   Điểm chuẩn    12994 non-null  float64
#  2   Học phí       13242 non-null  float64
#  3   tên ccta      13270 non-null  object
#  4   điểm ccta     13270 non-null  object
#  5   điểm quy đổi  13270 non-null  float64
#  6   hk10          13270 non-null  int64
#  7   hk11          13270 non-null  int64
#  8   hk12          13270 non-null  int64
#  9   hl10          13270 non-null  int64
#  10  hl11          13270 non-null  float64
#  11  hl12          13270 non-null  float64
#  12  nhom_nganh    13259 non-null  float64
#  13  ma_xet_tuyen  13270 non-null  object
# dtypes: float64(6), int64(4), object(4)
# memory usage: 1.4+ MB

# %% [markdown]
# Tổ hợp môn: có null
# Điểm chuẩn: có null
# Học phí: có null
# nhom_nganh: có null

# %%
len(data)
# Out:
# 13270

# %%
print(data["Tổ hợp môn"].isnull()==True)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 13265    False
# 13266    False
# 13267    False
# 13268    False
# 13269    False
# Name: Tổ hợp môn, Length: 13270, dtype: bool

# %%
# Check for null values in "Tổ hợp môn" column
print("Null values in 'Tổ hợp môn' column:")
print("\nRows where 'Tổ hợp môn' is null:")
null_rows = data[data["Tổ hợp môn"].isnull()]
print(null_rows)

# Check for null values in "Điểm chuẩn" column
print("Null values in 'Điểm chuẩn' column:")
print("\nRows where 'Điểm chuẩn' is null:")
null_rows = data[data["Điểm chuẩn"].isnull()]
print(null_rows)

# Check for null values in "Học phí" column
print("Null values in 'Học phí' column:")
print("\nRows where 'Học phí' is null:")
null_rows = data[data["Học phí"].isnull()]
print(null_rows)        

# Check for null values in "nhom_nganh" column
print("Null values in 'nhom_nganh' column:")
print("\nRows where 'nhom_nganh' is null:")
null_rows = data[data["nhom_nganh"].isnull()]
print(null_rows)
# Out:
# Null values in 'Tổ hợp môn' column:
#
# Rows where 'Tổ hợp môn' is null:
#       Tổ hợp môn  Điểm chuẩn     Học phí tên ccta điểm ccta  điểm quy đổi  \
# 6217         NaN        15.5  72000000.0        0         0           0.0
# 6218         NaN        15.5  72000000.0        0         0           0.0
# 6219         NaN        15.5  72000000.0        0         0           0.0
# 6220         NaN        15.5  72000000.0        0         0           0.0
# 6221         NaN        15.5  72000000.0        0         0           0.0
# ...          ...         ...         ...      ...       ...           ...
# 12357        NaN         NaN  50000000.0        0         0           0.0
# 12363        NaN         NaN  50000000.0        0         0           0.0
# 12369        NaN         NaN  50000000.0        0         0           0.0
# 12375        NaN         NaN  50000000.0        0         0           0.0
# 12381        NaN         NaN  50000000.0        0         0           0.0
#
# ...
